# %%
import pandas as pd  #pacotes
import numpy as np   #calculo numerico
import glob          #listas
#Codigo para declarar um pyarrow parquet - Willian - 29/05/2018
import pyarrow.parquet as pq
import os, sys       #funcoes para gravação de arquivos
from os import path
import datetime      #funcao datetime

# %%
def extract_epoch(filename):
  initial = str(filename).find('AngraRun') + 6
  final = str(filename).find('AngraRun') + 24
  sub = str(filename)[initial:final]
  epoch = ''.join(i for i in sub if i.isdigit())
  #print(epoch)
  return(epoch)

# %%
def find_interval_date(datein, datefi):  #enviar formato yyyy-mm-dd
    
    #print('{0:s}  {1:s}  {2:s}'.format(datein[0:4],datein[5:7],datein[8:10]))
    ts_datein = int(datetime.datetime(int(datein[0:4]),int(datein[5:7]),int(datein[8:10]),0,0).timestamp())
    #print(ts_datein)
    ts_datefi = int(datetime.datetime(int(datefi[0:4]),int(datefi[5:7]),int(datefi[8:10]),23,59).timestamp())
    #print(ts_datefi)
    
    fileparq  = '/data/processed/2020_phase2/AngraRun_1*.parq'  #nova pasta dos processados - 22/05/2025
    #fileparq  = '/data/processed/2020_phase2/AngraRun_1*.parq'  #nova pasta dos processados - 05/04/2021

    listparq = glob.glob(fileparq)
    interval_list = []
    i_fator = 1000  #novo v4 divide por 1000 - 05/04/2021

    #print(listparq)
    
    for file in listparq:
        #print(file)
        #i_filedate = int(int(extract_epoch(file))/10000)
        #if file[(str(file).find('AngraRun')+22):(str(file).find('AngraRun')+24)] == 'v2':
        #    i_fator = 10000
        #else:
        #    i_fator = 1000
        i_filedate = int(extract_epoch(file))/i_fator  # somente se não for v2 divide por 1000 (por que?)
        day_filedate = datetime.datetime.fromtimestamp(i_filedate).day
        month_filedate = datetime.datetime.fromtimestamp(i_filedate).month
        year_filedate = datetime.datetime.fromtimestamp(i_filedate).year
        ts_filedate = int(datetime.datetime(year_filedate,month_filedate,day_filedate,0,0).timestamp())
        #print('data/hora run: {0:d}-{1:d}-{2:d}'.format(year_filedate,month_filedate,day_filedate))
        if ts_filedate >= ts_datein and ts_filedate <= ts_datefi: 
            interval_list.append(file)
    #print(interval_list)    
    return(interval_list)

# %%
def find_interval_date_pair(datein, datefi, sdir):  #enviar formato yyyy-mm-dd
    
    ts_datein = int(datetime.datetime(int(datein[0:4]),int(datein[5:7]),int(datein[8:10]),0,0).timestamp())
    ts_datefi = int(datetime.datetime(int(datefi[0:4]),int(datefi[5:7]),int(datefi[8:10]),23,59).timestamp())
    
    fileparq  = sdir+'/*.parq'  #nova pasta dos processados - 05/04/2021
    listparq = glob.glob(fileparq)
    interval_list = []
    i_fator = 1000  #novo v4 divide por 1000 - 05/04/2021
    
    for file in listparq:
        #print(file)
        i_filedate = int(extract_epoch(file))/i_fator  # somente se não for v2 divide por 1000 (por que?)
        day_filedate = datetime.datetime.fromtimestamp(i_filedate).day
        month_filedate = datetime.datetime.fromtimestamp(i_filedate).month
        year_filedate = datetime.datetime.fromtimestamp(i_filedate).year
        ts_filedate = int(datetime.datetime(year_filedate,month_filedate,day_filedate,0,0).timestamp())
        print('{:s} >> data/hora run: {:d}-{:d}-{:d}'.format(file,year_filedate,month_filedate,day_filedate))
        if ts_filedate >= ts_datein and ts_filedate <= ts_datefi: 
            interval_list.append(file)
        
    return(interval_list)

# %%
#Exemplo para encontrar intervalos (desabilitado para não gerar prints)
'''
lista = find_interval_date('2018-03-19','2018-03-20')

for file in lista:
    #print (file)
    i_filedate = int(int(extract_epoch(file))/10000)
    day_filedate = datetime.datetime.fromtimestamp(i_filedate).day
    month_filedate = datetime.datetime.fromtimestamp(i_filedate).month
    year_filedate = datetime.datetime.fromtimestamp(i_filedate).year
    #print('data/hora run: {0:d}-{1:d}-{2:d}'.format(year_filedate,month_filedate,day_filedate))
'''
# Out:
# "\nlista = find_interval_date('2018-03-19','2018-03-20')\n\nfor file in lista:\n    #print (file)\n    i_filedate = int(int(extract_epoch(file))/10000)\n    day_filedate = datetime.datetime.fromtimestamp(i_filedate).day\n    month_filedate = datetime.datetime.fromtimestamp(i_filedate).month\n    year_filedate = datetime.datetime.fromtimestamp(i_filedate).year\n    #print('data/hora run: {0:d}-{1:d}-{2:d}'.format(year_filedate,month_filedate,day_filedate))\n"

# %%
#find_interval_date('2018-03-19','2018-03-21')

# %%
lista = find_interval_date_pair('2024-09-01','2024-12-31','q:/angra/2024_stop')

for file in lista:
    #print (file)
    i_filedate = int(int(extract_epoch(file))/10000)
    day_filedate = datetime.datetime.fromtimestamp(i_filedate).day
    month_filedate = datetime.datetime.fromtimestamp(i_filedate).month
    year_filedate = datetime.datetime.fromtimestamp(i_filedate).year
    #print('data/hora run: {0:d}-{1:d}-{2:d}'.format(year_filedate,month_filedate,day_filedate))
# Out:
# q:/angra/2024_stop\AngraRun_1730354960006_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730356763507_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730358581559_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730360407353_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730362227659_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730364046119_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730365849320_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730367661312_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730369480876_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730371301360_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730373101189_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730374913067_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730376730565_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730378544784_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730380368389_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730382186505_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730383989426_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730385812601_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730387621947_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730389434406_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730391249198_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730393067113_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730394888786_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730396704536_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730398534625_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730400341349_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730402147854_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730403958090_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730405777286_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730407603428_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730409417113_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730411238391_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730413046650_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730414864522_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730416678330_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730418480384_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730420296738_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730422104252_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730423920438_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730425730922_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730427549821_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730429368286_processed_v5.parq >> data/hora run: 2024-10-31
# q:/angra/2024_stop\AngraRun_1730431179135_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730432999130_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730434817111_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730436631408_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730438451297_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730440272050_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730442065212_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730443895438_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730445701569_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730447512561_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730449333899_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730451151566_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730452963336_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730454779549_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730456590478_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730458402000_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730460214468_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730462030319_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730463838909_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730465678924_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730467484881_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730469308121_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730471113543_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730472941653_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730474758820_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730476554093_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730478373100_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730480185899_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730482000776_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730483818781_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730485630714_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730487468314_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730489272549_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730491081363_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730492899187_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730494705956_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730496524207_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730498337984_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730500159446_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730501974520_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730503785995_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730505598678_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730507407189_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730509225540_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730511035833_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730512866440_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730514667078_processed_v5.parq >> data/hora run: 2024-11-1
# q:/angra/2024_stop\AngraRun_1730516485896_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730518297719_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730520126244_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730521932618_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730523758512_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730525584186_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730527385194_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730529190028_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730531012881_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730532819893_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730534638175_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730536445102_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730538270274_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1730540081469_processed_v5.parq >> data/hora run: 2024-11-2
# q:/angra/2024_stop\AngraRun_1
processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1730988396197_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1730990213548_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1731006548580_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1731008365101_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1731013811436_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1731015618897_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1731017439601_processed_v5.parq >> data/hora run: 2024-11-7
# q:/angra/2024_stop\AngraRun_1731046476350_processed_v5.parq >> data/hora run: 2024-11-8
# q:/angra/2024_stop\AngraRun_1731060994515_processed_v5.parq >> data/hora run: 2024-11-8
# q:/angra/2024_stop\AngraRun_1731104547597_processed_v5.parq >> data/hora run: 2024-11-8
# q:/angra/2024_stop\AngraRun_1731111801721_processed_v5.parq >> data/hora run: 2024-11-8
# q:/angra/2024_stop\AngraRun_1731115425634_processed_v5.parq >> data/hora run: 2024-11-8
# q:/angra/2024_stop\AngraRun_1731122694328_processed_v5.parq >> data/hora run: 2024-11-9
# q:/angra/2024_stop\AngraRun_1731129951313_processed_v5.parq >> data/hora run: 2024-11-9
# q:/angra/2024_stop\AngraRun_1731133577905_processed_v5.parq >> data/hora run: 2024-11-9
# q:/angra/2024_stop\AngraRun_1731144464491_processed_v5.parq >> data/hora run: 2024-11-9

# %%
def test_import_function(s):
    print('{0:s}'.format(s))

# %%
# função para fitar a exponencial de tempo para captura de neutron e background

### antigos coeficientes

#def fnt_fit_signal(x):
#    return (1.3933E5 * np.exp(-x/7.92E3)) + (6.34E4 * np.exp(-x/1.232E1))
#def fnt_fit_signalB(x):  #Background
#    return (1.3933E5 * np.exp(-x/7.92E3))
#def fnt_fit_signalN(x):  #Captura de Neutron
#    return (6.34E4 * np.exp(-x/1.232E1))

# %%
def fnt_fit_signal(x):
    return (2.03614188E3 * np.exp(-x/9.19327880E3)) + (1.69257858E4 * np.exp(-x/1.41105404E1))
def fnt_fit_signalB(x):  #Background
    return (2.03614188E3 * np.exp(-x/9.19327880E3))
def fnt_fit_signalN(x):  #Captura de Neutron
    return (1.69257858E4 * np.exp(-x/1.41105404E1))

# %%
fileparq  = 'Q:/angra/2024_stop/*.parq'  #nova pasta dos processados - 05/04/2021
#fileparq  = '/data2/processed/*'  #nova pasta dos processados - 05/04/2021
#fileparq  = '/data3/processed/2*'  #nova pasta dos processados - 05/04/2021
#fileparq  = '/data2/processed/A*'  #nova pasta dos processados - 05/04/2021
listparq = glob.glob(fileparq)
print(listparq)
# Out:
# ['Q:/angra/2024_stop\\AngraRun_1730354960006_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730356763507_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730358581559_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730360407353_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730362227659_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730364046119_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730365849320_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730367661312_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730369480876_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730371301360_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730373101189_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730374913067_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730376730565_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730378544784_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730380368389_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730382186505_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730383989426_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730385812601_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730387621947_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730389434406_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730391249198_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730393067113_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730394888786_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730396704536_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730398534625_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730400341349_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730402147854_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730403958090_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730405777286_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730407603428_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730409417113_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730411238391_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730413046650_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730414864522_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730416678330_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730418480384_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730420296738_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730422104252_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730423920438_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730425730922_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730427549821_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730429368286_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730431179135_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730432999130_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730434817111_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730436631408_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730438451297_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730440272050_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730442065212_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730443895438_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730445701569_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730447512561_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730449333899_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730451151566_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730452963336_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730454779549_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730456590478_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730458402000_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730460214468_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730462030319_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730463838909_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1730465678924_processed_v5.parq', 'Q:/angra/2024_stop\\AngraRun_1 ...
